# %% [markdown]
# <a href="https://colab.research.google.com/github/RosiKvb/ScheduleAMeet/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hod():
    print("With which department head do you want to set a meet?")
    print("1.'James' from Computer Science")
    print("2.'Nick' from Electrical")
    print("3.'Tom' from Mechanical")
    print("enter your choice: ")
    choice1=int(input())
    if choice1==1:
        c=input("Enter month: ")
        a=int(input("Enter date: "))
        b=int(input("Enter time: "))
        print("Your meeting is scheduled with James on "+str(a)+"th of "+c+" at "+str(b)+"hrs IST.")
    elif choice1==2:
        c=input("Enter month: ")
        a=int(input("Enter date: "))
        b=int(input("Enter time: "))
        print("Your meeting is scheduled with Nick on "+str(a)+"th of "+c+" at "+str(b)+"hrs IST.")
    elif choice1==3:
        c=input("Enter month: ")
        a=int(input("Enter date: "))
        b=int(input("Enter time: "))
        print("Your meeting is scheduled with Tom on "+str(a)+"th of "+c+" at "+str(b)+"hrs IST.")
    else:
        print("Enter input between 1-3 :(")
        return 0
    
def sl():
    print("With which department Senior Lecturer do you want to set a meet?")
    print("1.'Robert' from Computer Science")
    print("2.'Justin' from Electrical")
    print("3.'Chris' from Mechanical")
    choice2=int(input("enter your choice: "))
    if choice2==1:
        c=input("Enter month: ")
        a=int(input("Enter date: "))
        b=int(input("Enter time: "))
        print("Your meeting is scheduled with Robert on "+str(a)+"th of "+c+" at "+str(b)+"hrs IST.")
    elif choice2==2:
        c=input("Enter month: ")
        a=int(input("Enter date: "))
        b=int(input("Enter time: "))
        print("Your meeting is scheduled with Justin on "+str(a)+"th of "+c+" at "+str(b)+"hrs IST.")
    elif choice2==3:
        c=input("Enter month: ")
        a=int(input("Enter date: "))
        b=int(input("Enter time: "))
        print("Your meeting is scheduled with Chris on "+str(a)+"th of "+c+" at "+str(b)+"hrs IST.")
    else:
        print("Enter choice between 1-3 :(")
        return 0
    
def jl():
    print("With which department Junior Lecturer do you want to set a meet?")
    print("1.'Gates' from Computer Science")
    print("2.'Elon' from Electrical")
    print("3.'Zayn' from Mechanical")
    choice3=int(input("enter your choice: "))
    if choice3==1:
        c=input("Enter month: ")
        a=int(input("Enter date: "))
        b=int(input("Enter time: "))
        print("Your meeting is scheduled with Gates on "+str(a)+"th of "+c+" at "+str(b)+"hrs IST.")
    elif choice3==2:
        c=input("Enter month: ")
        a=int(input("Enter date: "))
        b=int(input("Enter time: "))
        print("Your meeting is scheduled with Elon on "+str(a)+"th of "+c+" at "+str(b)+"hrs IST.")
    elif choice3==3:
        c=input("Enter month: ")
        a=int(input("Enter date: "))
        b=int(input("Enter time: "))
        print("Your meeting is scheduled with Zayn on "+str(a)+"th of "+c+" at "+str(b)+"hrs IST.")
    else:
        print("Enter choice between 1-3 :(")
        return 0

def bot():
    print("Your name please: ")
    name=input()
    print("Hello "+name+" sir, with whom do you want to set a one on one meet?")
    print("1.Heads of respective departments")
    print("2.Senior Lecturers")
    print("3.Junior Lecturers")
    choice=int(input("Enter your choice: "))
    if choice==1:
        hod()
    elif choice==2:
        sl()
    elif choice==3:
        jl()
    else:
        print("Please select between 1-3 :(")
        
            
bot()
